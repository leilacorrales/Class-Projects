# %% [markdown]
# ### Opening Data + Observations + Cleaning
#
# Details:

# %%
import pandas as pd

df = pd.read_csv("C:\Users\anici\Class-Projects\CIS 3250\Maven Business School(final).xlsx")
print(df.head())
