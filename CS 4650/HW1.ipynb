# %% [markdown]
# # HW 1 - Map Reduce
# Using the weather data files from the Topic 9 lecture, write a Map/Reduce job that will examine the Wind Direction and Temperature values for each data point, then produce a report that lists, for each Wind Direction, the minimum temperature recorded, the maximum temperature recorded, and the number of times that Wind Direction appeared in the data.  Here is what a sample output line would look like:
#
# 70    {"low":-333,"high":278,"count":502}
